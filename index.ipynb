# %% [markdown]
# # Supplementary materials for "Persistent ocean-shelf transport across the North West European Shelf edge"
#
# A. Palóczy*, J. Hopkins, A. Wise, J. Huthnance
#
# National Oceanography Centre (*<apaloczy@noc.ac.uk>)

# %% [markdown]
# **Jupyter notebooks to reproduce manuscript figures**
# ---

# %% [markdown]
# * [Figure 1](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig1.ipynb)
# * [Figure 2](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig2.ipynb)
# * [Figure 3](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig3.ipynb)
# * [Figures 4 and 5](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/figs4-5.ipynb)
# * [Figure 6](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig6.ipynb)
# * [Figure 7](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig7.ipynb)

# %% [markdown]
# Figure 8 is a summary schematic. The file is provided both in [`.png`](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig8.png) and vector [`.svg`](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/blob/main/plot_figs/fig8.svg) formats.
#
# Figure S1 can be reproduced by running the script `03-calc_Nshelf-NSBC_figS1.py` in the `../proc` directory.
