# %% [markdown]
# # Supplementary materials for "Persistent ocean-shelf transport across the North West European Shelf edge"
#
# A. Palóczy*, J. Hopkins, A. Wise, J. Huthnance
#
# National Oceanography Centre | *<apaloczy@noc.ac.uk> |

# %% [markdown]
# **Jupyter notebooks to reproduce manuscript figures**
# ---

# %% [markdown]
# * [Figure 1](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig1.ipynb)
# * [Figure 2](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig2.ipynb)
# * [Figure 3](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig3.ipynb)
# * [Figure 4](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig4.ipynb)
# * [Figure 5](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig5.ipynb)
# * [Figure 6](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig6.ipynb)
# * [Figure 7](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig7.ipynb)

# %% [markdown]
# Figure 8 is a summary schematic. The file is provided both in [`.png`](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig8.png) and vector [`.svg`](https://github.com/apaloczy/xshelfGeostrophicTransportNWES/plot_figs/fig8.svg) formats.
